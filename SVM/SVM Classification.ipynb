# %%
import pandas as pd

# %%
dataset = pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dependent=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train[0]
# Out:
# array([ 0.81203707,  0.7926083 , -0.99250926])

# %%
from sklearn.svm import SVC
classifier=SVC(C=1.0, kernel='rbf', gamma='scale')

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y_test, y_pred)
clf_report = classification_report(y_test, y_pred)

# %%
cm
# Out:
# array([[77,  8],
#        [ 4, 45]])

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
#param_grid = {'kernel':['rbf','sigmoid','linear'], 
#             'C':[10,100,1000,2000,3000], 'gamma':['auto','scale']}

# %%
classifier=SVC(C=1.0, kernel='rbf', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=1.0, kernel='sigmoid', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        85
#            1       0.79      0.67      0.73        49
#
#     accuracy                           0.81       134
#    macro avg       0.81      0.78      0.79       134
# weighted avg       0.81      0.81      0.81       134

# %%
classifier=SVC(C=1.0, kernel='linear', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        85
#            1       0.88      0.71      0.79        49
#
#     accuracy                           0.86       134
#    macro avg       0.86      0.83      0.84       134
# weighted avg       0.86      0.86      0.85       134

# %%
classifier=SVC(C=10, kernel='rbf', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=10, kernel='sigmoid', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85        85
#            1       0.78      0.59      0.67        49
#
#     accuracy                           0.79       134
#    macro avg       0.79      0.75      0.76       134
# weighted avg       0.79      0.79      0.78       134

# %%
classifier=SVC(C=10, kernel='linear', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        85
#            1       0.88      0.71      0.79        49
#
#     accuracy                           0.86       134
#    macro avg       0.86      0.83      0.84       134
# weighted avg       0.86      0.86      0.85       134

# %%
classifier=SVC(C=100, kernel='rbf', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=1000, kernel='rbf', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        85
#            1       0.90      0.90      0.90        49
#
#     accuracy                           0.93       134
#    macro avg       0.92      0.92      0.92       134
# weighted avg       0.93      0.93      0.93       134

# %%
classifier=SVC(C=2000, kernel='rbf', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93        85
#            1       0.88      0.90      0.89        49
#
#     accuracy                           0.92       134
#    macro avg       0.91      0.91      0.91       134
# weighted avg       0.92      0.92      0.92       134

# %%
classifier=SVC(C=3000, kernel='rbf', gamma='scale')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        85
#            1       0.86      0.90      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=1.0, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=1.0, kernel='sigmoid', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        85
#            1       0.79      0.67      0.73        49
#
#     accuracy                           0.81       134
#    macro avg       0.81      0.78      0.79       134
# weighted avg       0.81      0.81      0.81       134

# %%
classifier=SVC(C=1.0, kernel='linear', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        85
#            1       0.88      0.71      0.79        49
#
#     accuracy                           0.86       134
#    macro avg       0.86      0.83      0.84       134
# weighted avg       0.86      0.86      0.85       134

# %%
classifier=SVC(C=10, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=100, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=1000, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        85
#            1       0.90      0.90      0.90        49
#
#     accuracy                           0.93       134
#    macro avg       0.92      0.92      0.92       134
# weighted avg       0.93      0.93      0.93       134

# %%
classifier=SVC(C=2000, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93        85
#            1       0.88      0.90      0.89        49
#
#     accuracy                           0.92       134
#    macro avg       0.91      0.91      0.91       134
# weighted avg       0.92      0.92      0.92       134

# %%
classifier=SVC(C=3000, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        85
#            1       0.86      0.90      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
classifier=SVC(C=1000, kernel='rbf', gamma='auto')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        85
#            1       0.90      0.90      0.90        49
#
#     accuracy                           0.93       134
#    macro avg       0.92      0.92      0.92       134
# weighted avg       0.93      0.93      0.93       134

# %%
import pickle
filename = "finalized_classifier_model.sav"
pickle.dump(classifier,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_classifier_model.sav",'rb'))

# %%
preinput = sc.transform([[55,10000,1]])

# %%
preinput
# Out:
# array([[1.69971595, 2.39635892, 1.00754728]])

# %%
result = loaded_model.predict(preinput)

# %%
result
# Out:
# array([1])
