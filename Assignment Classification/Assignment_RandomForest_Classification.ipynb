# %%
import pandas as pd
dataset = pd.read_csv('CKD.csv')

# %%
dataset.shape
# Out:
# (399, 25)

# %%
dataset.head(5)
# Out:
#    age         bp sg   al   su     rbc        pc         pcc          ba  \
# 0  2.0  76.459948  c  3.0  0.0  normal  abnormal  notpresent  notpresent
# 1  3.0  76.459948  c  2.0  0.0  normal    normal  notpresent  notpresent
# 2  4.0  76.459948  a  1.0  0.0  normal    normal  notpresent  notpresent
# 3  5.0  76.459948  d  1.0  0.0  normal    normal  notpresent  notpresent
# 4  5.0  50.000000  c  0.0  0.0  normal    normal  notpresent  notpresent
#
#           bgr  ...        pcv            wc        rc  htn  dm  cad  appet  \
# 0  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 1  148.112676  ...  34.000000  12300.000000  4.705597   no  no   no    yes
# 2   99.000000  ...  34.000000   8408.191126  4.705597   no  no   no    yes
# 3  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 4  148.112676  ...  36.000000  12400.000000  4.705597   no  no   no    yes
#
#      pe  ane classification
# 0   yes   no            yes
# ...

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.shape
# Out:
# (399, 28)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent=dataset[['classification_yes']]

# %%
dependent.value_counts()
# Out:
# classification_yes
# 1                     249
# 0                     150
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
param_grid={'criterion':['gini', 'entropy', 'log_loss'],
           'n_estimators':[10, 100],
           'max_features':['sqrt', 'log2',None]}
grid = GridSearchCV(RandomForestClassifier(),param_grid,refit=True,n_jobs=-1,verbose=3,scoring='f1_weighted')

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              scoring='f1_weighted', verbose=3)

# %%
y_pred = grid.predict(X_test)

# %%
grid_result = grid.cv_results_

# %%
table = pd.DataFrame.from_dict(grid_result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.078224      0.003650         0.034672        0.003050
# 1        0.558645      0.033870         0.054381        0.008886
# 2        0.061346      0.008257         0.026511        0.001456
# 3        0.545752      0.028178         0.041681        0.004267
# 4        0.065502      0.004090         0.025274        0.001644
# 5        0.602906      0.012087         0.047918        0.004168
# 6        0.060726      0.006236         0.024698        0.003027
# 7        0.540953      0.010541         0.044270        0.002401
# 8        0.059131      0.002482         0.026213        0.002267
# 9        0.535239      0.013461         0.045903        0.004194
# 10       0.067000      0.002418         0.028277        0.003448
# 11       0.645441      0.005799         0.047389        0.002495
# 12       0.064153      0.006965         0.029946        0.003584
# ...

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 100}

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score, roc_auc_score

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[50  1]
#  [ 1 81]]

# %% [markdown]
# Type1 error is 1 in the above confusion_matrix. And Type2 error is 1. Looks good on this resullt

# %%
clf=classification_report(y_test,y_pred)
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        51
#            1       0.99      0.99      0.99        82
#
#     accuracy                           0.98       133
#    macro avg       0.98      0.98      0.98       133
# weighted avg       0.98      0.98      0.98       133

# %% [markdown]
# Accuracy on the above result is 98% which is very good.

# %%
f1score = f1_score(y_test,y_pred)
print(f1score)
# Out:
# 0.9878048780487805

# %% [markdown]
# F1score value is closer to 98.78% which is very good.

# %%
roc_auc_score1 = roc_auc_score(y_test, grid.predict_proba(X_test)[:,1])
print(roc_auc_score1)
# Out:
# 0.9997608799617408

# %% [markdown]
# Roc_Auc_score is also 99.97%. This is also very good.
