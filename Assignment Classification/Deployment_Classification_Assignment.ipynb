# %%
import pickle as pkl
import pandas as pd

# %%
dataset = pd.read_csv("CKD.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent=dataset[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
loaded_model = pkl.load(open("Finalized_Assignment_classifier.sav",'rb'))

# %%
loaded_columns = pkl.load(open("columns.sav",'rb'))

# %%
input = {
    'age': 48,
    'bp': 80,
    'sg': 'a',
    'al': 1,
    'su': 0,
    'rbc': 'normal',
    'pc': 'normal',
    'pcc': 'notpresent',
    'ba': 'notpresent',
    'bgr': 121,
    'bu': 36,
    'sc': 1.2,
    'sod': 135,
    'pot': 4.5,
    'hemo': 15.4,
    'pcv': 44,
    'wc': 7800,
    'rc': 5.2,
    'htn': 'yes',
    'dm': 'no',
    'cad': 'no',
    'appet': 'good',
    'pe': 'no',
    'ane': 'no'
}

# %%
input_df=pd.DataFrame([input])

# %%
input_df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane'],
#       dtype='object')

# %%
input_df
# Out:
#    age  bp sg  al  su     rbc      pc         pcc          ba  bgr  ...  hemo  \
# 0   48  80  a   1   0  normal  normal  notpresent  notpresent  121  ...  15.4
#
#    pcv    wc   rc  htn  dm  cad  appet  pe ane
# 0   44  7800  5.2  yes  no   no   good  no  no
#
# [1 rows x 24 columns]

# %%
input_df=pd.get_dummies(input_df,dtype=int)

# %%
input_df.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv',
#        'wc', 'rc', 'sg_a', 'rbc_normal', 'pc_normal', 'pcc_notpresent',
#        'ba_notpresent', 'htn_yes', 'dm_no', 'cad_no', 'appet_good', 'pe_no',
#        'ane_no'],
#       dtype='object')

# %%
input_df
# Out:
#    age  bp  al  su  bgr  bu   sc  sod  pot  hemo  ...  rbc_normal  pc_normal  \
# 0   48  80   1   0  121  36  1.2  135  4.5  15.4  ...           1          1
#
#    pcc_notpresent  ba_notpresent  htn_yes  dm_no  cad_no  appet_good  pe_no  \
# 0               1              1        1      1       1           1      1
#
#    ane_no
# 0       1
#
# [1 rows x 24 columns]

# %%
input_df = input_df.reindex(columns=loaded_columns, fill_value=0)

# %%
input_df
# Out:
#    age  bp  al  su  bgr  bu   sc  sod  pot  hrmo  ...  rbc_normal  pc_normal  \
# 0   48  80   1   0  121  36  1.2  135  4.5     0  ...           1          1
#
#    pcc_present  ba_present  htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  \
# 0            0           0        1       0        0          0       0
#
#    ane_yes
# 0        0
#
# [1 rows x 27 columns]

# %%
loaded_model.predict(input_df)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# array([0])
